# %%
import cv2

cv2.__version__
# Out:
# '4.9.0'

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=[10,10])

bgr = cv2.imread("img/coca-cola-logo.png")
rgb = cv2.cvtColor(bgr, cv2.COLOR_BGR2RGB)
print(rgb.shape)
plt.imshow(rgb)
# Out:
# (700, 700, 3)
